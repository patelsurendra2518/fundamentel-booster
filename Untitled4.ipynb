# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
fav_number = input("Enter your favourite number: ")
# Out:
# Enter your name:  patel surendra
# Enter your age:  23
# Enter your favourite number:  7

# %%
print("\n User Information ")
print("Hello,", name + "! ")
print("Your age is:", age)
print("Your favourite number is:", fav_number)
# Out:
#  User Information
# Hello, patel surendra !
# Your age is: 23
# Your favourite number is: 7

# %%
print("\nNice to meet you,", name + "!")
print("You will be", int(age) + 1, "years old next year 😄")
# Out:
# Nice to meet you, patel surendra !
# You will be 24 years old next year 😄
