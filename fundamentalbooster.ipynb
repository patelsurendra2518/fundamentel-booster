# %%
print("patel surendra")
# Out:
# patel surendra

# %%
username= "patel surendra"
print("heyy"+username)
# Out:
# heyypatel surendra

# %%
age = int(input("Enter your age: ")) 
height = float(input("Enter your height in meters: "))  

print(" you are", age , "years old and", height,"meters tall")
# Out:
# Enter your age:  23
# Enter your height in meters:  170.0
#  you are 23 years old and 170.0 meters tall

# %%
id = 12724
name = "patel surendra "
isAuth = True
courses = ["Python","ML","AI","Data analysis"]

print("Id:",id,name )
# Out:
# Id: 12724 patel surendra

# %%
data=16
print(data) 
data="data analysis"
print(data)
# Out:
# 16
# data analysis

# %%
A = 16
b = " red & white " 
c = 75.90

print(A) 
print(b)
print(c)
# Out:
# 16
#  red & white
# 75.9

# %%
num1 = int(input("Enter num1:"))
num2 = int(input("Enter num2:"));
print("Addition : ",num1+num2);
# Out:
# Enter num1: 34
# Enter num2: 89
# Addition :  123

# %%
x= 7
print(type(x))
# Out:
# <class 'int'>

# %%
s=7.0
print(type(s))
# Out:
# <class 'float'>

# %%
a = 10
n =str(a)

print(n)
print(type(n))
# Out:
# 10
# <class 'str'>

# %%
a = 78
b = 40

addition = a + b
print(addition)
# Out:
# 118

# %%
a = 
b = 45

subtraction = a - b
print (subtraction)
